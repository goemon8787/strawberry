# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ma = [19417643, 19466580, 19523173, 19424301, 19429332, 19451457, 19377286, 19395585]
raw = [19426373, 19453789, 19533324, 19526423, 19493838, 19375153, 19458799, 19551753]

# %%
x = np.arange(len(ma))

# %%
plt.plot(x, ma, "r")
plt.plot(x, raw, "b")
plt.show()

# %%
np.std(ma)
# Out:
# 42384.148410512804

# %%
np.std(raw)
# Out:
# 56226.10279043

# %%
np.mean(ma)
# Out:
# 19435669.625

# %%
np.mean(raw)
# Out:
# 19477431.5
