# %%
import pandas as pd

# %%
df_kk = pd.read_csv("./data/kk.csv")

# %%
df_kk["産地名"].unique().shape
# Out:
# (27,)

# %%
df_kk.iloc[50:100]
# Out:
#        年  月   日 曜日  品目名  品目コード  産地名  産地コード      数量    価格 対前日比（数量） 対前日比（価格）
# 50  2012  1  20  金  いちご  46100  栃　木    9.0   64984  1095      NaN      NaN
# 51  2012  1  20  金  いちご  46100  福　岡   40.0   32354  1536      NaN      NaN
# 52  2012  1  20  金  いちご  46100  佐　賀   41.0   22169  1347      NaN      NaN
# 53  2012  1  21  土  いちご  46100  NaN    NaN  233220  1300    112.0    103.0
# 54  2012  1  21  土  いちご  46100  栃　木    9.0   77670  1119      NaN      NaN
# 55  2012  1  21  土  いちご  46100  福　岡   40.0   34557  1572      NaN      NaN
# 56  2012  1  21  土  いちご  46100  愛　知   23.0   22044  1239      NaN      NaN
# 57  2012  1  23  月  いちご  46100  NaN    NaN  290779  1338    124.7    102.9
# 58  2012  1  23  月  いちご  46100  栃　木    9.0   83791  1143      NaN      NaN
# 59  2012  1  23  月  いちご  46100  福　岡   40.0   48990  1586      NaN      NaN
# 60  2012  1  23  月  いちご  46100  熊　本   43.0   30443  1422      NaN      NaN
# ...

# %%
df_tk = pd.read_csv("./data/tk.csv")
# Out:
# /home/yamashitakeisuke/.anyenv/envs/pyenv/versions/anaconda3-2020.11/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_tk[:50]
# Out:
#        年  月  日 曜日   都市名  都市コード  品目名  品目コード  産地名  産地コード      数量    価格 対前日比（数量）  \
# 0   2012  1  5  木   仙台市    401  いちご  46100  NaN    NaN   26412  1498    173.1
# 1   2012  1  5  木   仙台市    401  いちご  46100  宮　城    4.0   13555  1460      NaN
# 2   2012  1  5  木   仙台市    401  いちご  46100  佐　賀   41.0    6115  1624      NaN
# 3   2012  1  5  木   仙台市    401  いちご  46100  福　岡   40.0    2210  1955      NaN
# 4   2012  1  5  木   東京都   1301  いちご  46100  NaN    NaN  318360  1447    315.8
# 5   2012  1  5  木   東京都   1301  いちご  46100  栃　木    9.0  134351  1289      NaN
# 6   2012  1  5  木   東京都   1301  いちご  46100  福　岡   40.0   48933  1871      NaN
# 7   2012  1  5  木   東京都   1301  いちご  46100  茨　城    8.0   35531  1253      NaN
# 8   2012  1  5  木   横浜市   1401  いちご  46100  NaN    NaN   50381  1297    407.8
# 9   2012  1  5  木   横浜市   1401  いちご  46100  栃　木    9.0   29506  1147      NaN
# 10  2012  1  5  木   横浜市   1401  いちご  46100  長　崎   42.0    9254  1497      NaN
# ...
